# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("../data/raw/cardekho.csv")

# %%
df.head(10)
# Out:
#                                    name  year  selling_price  km_driven  \
# 0                Maruti Swift Dzire VDI  2014         450000     145500
# 1          Skoda Rapid 1.5 TDI Ambition  2014         370000     120000
# 2              Honda City 2017-2020 EXi  2006         158000     140000
# 3             Hyundai i20 Sportz Diesel  2010         225000     127000
# 4                Maruti Swift VXI BSIII  2007         130000     120000
# 5         Hyundai Xcent 1.2 VTVT E Plus  2017         440000      45000
# 6          Maruti Wagon R LXI DUO BSIII  2007          96000     175000
# 7                    Maruti 800 DX BSII  2001          45000       5000
# 8                      Toyota Etios VXD  2011         350000      90000
# 9  Ford Figo Diesel Celebration Edition  2013         200000     169000
#
#      fuel seller_type transmission         owner  mileage(km/ltr/kg)  engine  \
# 0  Diesel  Individual       Manual   First Owner               23.40  1248.0
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(1202)

# %%
df = df.drop_duplicates()

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# renaming mileage 
df = df.rename(columns={"mileage(km/ltr/kg)": "mileage"})

# %%
df.sample(3)
# Out:
#                                   name  year  selling_price  km_driven  \
# 3943            Maruti Swift Dzire VXI  2014         480000      72000
# 232        Maruti Wagon R LXI Optional  2016         350000     140000
# 5593  Chevrolet Enjoy TCDi LT 7 Seater  2013         355000     136000
#
#         fuel seller_type transmission         owner  mileage  engine  \
# 3943  Petrol  Individual       Manual   First Owner    19.10  1197.0
# 232   Petrol  Individual       Manual   First Owner    20.51   998.0
# 5593  Diesel  Individual       Manual  Second Owner    18.20  1248.0
#
#      max_power  seats
# 3943      85.8    5.0
# 232      67.04    5.0
# 5593      73.8    7.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6926 entries, 0 to 8125
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           6926 non-null   object
#  1   year           6926 non-null   int64
#  2   selling_price  6926 non-null   int64
#  3   km_driven      6926 non-null   int64
#  4   fuel           6926 non-null   object
#  5   seller_type    6926 non-null   object
#  6   transmission   6926 non-null   object
#  7   owner          6926 non-null   object
#  8   mileage        6718 non-null   float64
#  9   engine         6718 non-null   float64
#  10  max_power      6721 non-null   object
#  11  seats          6718 non-null   float64
# dtypes: float64(3), int64(3), object(6)
# memory usage: 703.4+ KB

# %%
# max_power fromonject to float64
df["max_power"] = pd.to_numeric(df["max_power"], errors="coerce")

# %%
df["max_power"].dtype
# Out:
# dtype('float64')

# %%
df["brand"] = df["name"].str.strip().str.split().str[0]

# %%
df.sample(3)
# Out:
#                          name  year  selling_price  km_driven    fuel  \
# 375   Toyota Camry 2.5 Hybrid  2016        2000000      68089  Petrol
# 1815     Mahindra Jeep MM 540  1995         160000      90000  Diesel
# 3940   Chevrolet Spark 1.0 LT  2016         160000      50000  Petrol
#
#            seller_type transmission         owner  mileage  engine  max_power  \
# 375   Trustmark Dealer    Automatic   First Owner    19.16  2494.0      157.7
# 1815        Individual       Manual   Third Owner      NaN     NaN        NaN
# 3940        Individual       Manual  Second Owner    16.20   995.0       62.1
#
#       seats      brand
# 375     5.0     Toyota
# 1815    NaN   Mahindra
# 3940    5.0  Chevrolet

# %%
df = df.drop(columns=["name"])

# %%
df.sample(3)
# Out:
#       year  selling_price  km_driven    fuel seller_type transmission  \
# 8121  2013         260000      50000  Petrol  Individual       Manual
# 6932  2007          55000      75958  Diesel  Individual       Manual
# 5579  2008         585000     120000  Diesel  Individual    Automatic
#
#              owner  mileage  engine  max_power  seats       brand
# 8121  Second Owner    18.90   998.0       67.1    5.0      Maruti
# 6932  Second Owner    17.88  1396.0       52.8    5.0        Tata
# 5579   First Owner    14.30  1968.0      140.0    5.0  Volkswagen

# %%
# i wanna create car age for the dataset
from datetime import datetime
current_year = datetime.now().year

df["car_age"] = current_year - df["year"]
df = df.drop(columns=["year"])

# %%
df.sample(3)
# Out:
#       selling_price  km_driven    fuel seller_type transmission         owner  \
# 601          555000      20000  Petrol  Individual       Manual  Second Owner
# 3055         190000      80000  Petrol  Individual       Manual  Second Owner
# 5184         150000      90000  Petrol  Individual       Manual   Third Owner
#
#       mileage  engine  max_power  seats   brand  car_age
# 601      15.8  1499.0      110.0    5.0    Ford       11
# 3055     16.8   796.0       34.2    8.0  Maruti       10
# 5184     13.4  1794.0      125.0    5.0  Toyota       20

# %%
miss = (df.isna().sum()/df.shape[0])*100
miss[miss>0]
# Out:
# mileage      3.003176
# engine       3.003176
# max_power    2.974300
# seats        3.003176
# dtype: float64

# %%
df.to_csv('../data/processed/car_sales_cleaned.csv', index=False)
